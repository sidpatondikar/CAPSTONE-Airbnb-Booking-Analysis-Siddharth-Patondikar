# %% [markdown]
# <a href="https://colab.research.google.com/github/sidpatondikar/CAPSTONE-1-AirBnB-Booking-Analysis-Siddharth-Patondikar/blob/main/Individual_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Airbnb Booking Analysis

# %% [markdown]
# Airbnb is an online marketplace that allows individuals to rent out their homes, apartments, or rooms to travelers. Founded in 2008, the platform has grown to become one of the largest hospitality companies in the world, with over 4 million listings in more than 220 countries and regions. Airbnb offers a variety of accommodations, ranging from private rooms in shared apartments to entire houses and villas. The platform has revolutionized the way people travel by providing a more affordable and authentic alternative to traditional hotels, and has had a significant impact on the hospitality industry as a whole.

# %% [markdown]
# ### Summary
#
# Initially in our team we decided to take the airbnb dataset on our own and do individual EDA to get multiple perspectives on the same dataset. This is my individual notebook. I started with importing and analyzing data. Followed by data wrangling and EDA.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Python for Data Science/EDA Project/Airbnb NYC 2019.csv'

# %%
df = pd.read_csv(file_path)
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ## Handling Null Values

# %%
df.isnull().sum().reset_index()
# Out:
#                              index      0
# 0                               id      0
# 1                             name     16
# 2                          host_id      0
# 3                        host_name     21
# 4              neighbourhood_group      0
# 5                    neighbourhood      0
# 6                         latitude      0
# 7                        longitude      0
# 8                        room_type      0
# 9                            price      0
# 10                  minimum_nights      0
# 11               number_of_reviews      0
# 12                     last_review  10052
# 13               reviews_per_month  10052
# 14  calculated_host_listings_count      0
# 15                availability_365      0

# %% [markdown]
# Here there are a lot of null values for last review and review per month while very less for name and host_name. I found out the reason for this large null values first and then handled them.

# %% [markdown]
# ### Null values as a percentage of total values for each column

# %%
total_val = df.shape[0]
total_val
# Out:
# 48895

# %%
df_null = pd.DataFrame(df.isnull().sum()).reset_index()
df_null.rename(columns={'index':'columns',0:'percentage null'},inplace=True)
df_null['percentage null'] = df_null['percentage null'].apply(lambda x: round(x*100/total_val,2))
df_null
# Out:
#                            columns  percentage null
# 0                               id             0.00
# 1                             name             0.03
# 2                          host_id             0.00
# 3                        host_name             0.04
# 4              neighbourhood_group             0.00
# 5                    neighbourhood             0.00
# 6                         latitude             0.00
# 7                        longitude             0.00
# 8                        room_type             0.00
# 9                            price             0.00
# 10                  minimum_nights             0.00
# 11               number_of_reviews             0.00
# 12                     last_review            20.56
# 13               reviews_per_month            20.56
# 14  calculated_host_listings_count             0.00
# 15                availability_365             0.00

# %% [markdown]
# Here, I have created a new dataframe from the isnull().sum() output and renamed the columns.
#
# In the new dataframe, 2nd column is converted to percentage null by dividing it by total values: 48895. So I stored the total values in a variable called total_val and used the lambda function in percentage null column to do the changes. So finally, the above output shows null values in every column as percentage of total values.

# %% [markdown]
# ### Columns containing null values are :
# 1. name
# 2. host_name
# 3. last_review
# 4. reviews_per_month
#
# name and hostname has very less null values whereas last review and review per month column has significant null values of around 20.5%

# %%
df[df['last_review'].isna()]['number_of_reviews'].value_counts()
# Out:
# 0    10052
# Name: number_of_reviews, dtype: int64

# %%
df[df['reviews_per_month'].isna()]['number_of_reviews'].value_counts()
# Out:
# 0    10052
# Name: number_of_reviews, dtype: int64

# %% [markdown]
# ### Null values reason and outcome
#
# We can clearly see here that for the properties with 0 reviews, last review and number of reviews has null values. This make sense because if there are 0 reviews, how can there be number of reviews per month and last review date.
#
# To change this, I have replaced reviews_per_month to 0.

# %%
df2 = df.copy()
df2['reviews_per_month'].fillna(0,inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2.shape
# Out:
# (48895, 16)

# %% [markdown]
#  Removing the rows with null name (property name) and host name because they are very less when compared to total values.

# %%
df2 = df2[~df2['host_name'].isna()]
df2 = df2[~df2['name'].isna()]
df2.shape
# Out:
# (48858, 16)

# %% [markdown]
# Dropping unneccessary columns like id, host id and last review from the dataframe.

# %%
df2.drop(['id','host_id','last_review'],axis=1,inplace=True)

# %%
df2.isnull().sum()
# Out:
# name                              0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### EDA is done in the form of Univariate, Bivariate and Multivariate analysis

# %% [markdown]
# ## Univariate Analysis

# %%
df2.head()
# Out:
#                                                name    host_name  \
# 0                Clean & quiet apt home by the park         John
# 1                             Skylit Midtown Castle     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
df2['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ### How are the total listings distributed around NYC?
#
# The below graph represents the total lisitings distribution around 5 neighbourhood groups. Manhattan and Brooklyn has the most number of listings. Most people prefer to stay in these 2 neighbourhood groups.

# %%
plt.figure(figsize=(10,8))
df2['neighbourhood_group'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# This shows the total listings for each neighbourhood group. We can observe that Manhattan and Brooklyn has the most listings, while Staten Island has the least.

# %% [markdown]
# ### What are the different kind of room types available across the city?

# %%
df2['room_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# In the above graph, The most popular type of room is Entire home/apartment followed by private room.
#
# From this we can see that when booking Airbnb, people want privacy and prefer to opt for private rooms/house rather than shared.

# %% [markdown]
# ### Doing data wrangling on columns

# %%
df2.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48858.000000  48858.000000  48858.000000    48858.000000
# mean      40.728941    -73.952170    152.740309        7.012444
# std        0.054528      0.046159    240.232386       20.019757
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690090    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763107    -73.936280    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48858.000000       48858.000000                    48858.000000
# mean           23.273098           1.091124                        7.148369
# std            44.549898           1.597270                       32.964600
# min             0.000000           0.000000                        1.000000
# ...

# %% [markdown]
# Here we can see that for price and availability_365 columns min values is 0.
# 1. Price of a property cannot be 0.
# 2. If a room is available for 0 days that is not useful.
#
# So I have removed the records where either of these values are 0.

# %%
df2[df2['price']==0]
# Out:
#                                                     name     host_name  \
# 23161  Huge Brooklyn Brownstone Living, Close to it all.      Kimberly
# 25433      ★Hostel Style Room | Ideal Traveling Buddies★        Anisha
# 25634    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)  Martial Loft
# 25753                    Sunny, Quiet Room in Greenpoint        Lauren
# 25778      Modern apartment in the heart of Williamsburg       Aymeric
# 25794  Spacious comfortable master bedroom with nice ...       Adeyemi
# 25795  Contemporary bedroom in brownstone with nice view       Adeyemi
# 25796       Cozy yet spacious private brownstone bedroom       Adeyemi
# 26259                              the best you can find        Qiuchi
# 26841  Coliving in Brooklyn! Modern design / Shared room        Sergii
# 26866             Best Coliving space ever! Shared room.        Sergii
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# Price of a room cannot be 0. Hence, removing rows containing price 0.

# %%
df2.shape
# Out:
# (48858, 13)

# %%
df3 = df2[df2['price']!=0]
df3.shape
# Out:
# (48847, 13)

# %%
df3['price'].describe()
# Out:
# count    48847.000000
# mean       152.774705
# std        240.248498
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df3 = df3[df3['availability_365']!=0]

# %%
df3.shape
# Out:
# (31342, 13)

# %% [markdown]
# ### What is the room availabilty throughout the year?

# %%
df3['availability_365'].plot(kind='hist')
plt.title("Airbnb availability thoughout the year")
plt.xlabel("Days in year")
# Out:
# Text(0.5, 0, 'Days in year')

# %% [markdown]
# The above histrogram is made using hist plot in pyplot for availability_365 column. It shows the availability distribution of rooms.
#
# Most of the properties are available between 0 to 40 days in a year.

# %% [markdown]
# ### What is the distribution of reviews?

# %%
df3['number_of_reviews'].plot(kind='hist')
plt.title("Distribution of Reviews")
plt.xlabel("Number of reviews")
# Out:
# Text(0.5, 0, 'Number of reviews')

# %% [markdown]
# This histogram is made using pyplot with kind='hist'. It shows distribution of reviews.
# Most properties have between 0 to 50 reviews.

# %% [markdown]
# ### What are the reviews per month throughout the year?

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,2,1)
sns.histplot(df3['reviews_per_month'],binrange=[0,7])
plt.title("Reviews per month distribution")

plt.subplot(1,2,2)
sns.histplot(df3['reviews_per_month'],binrange=[0,1])
plt.title("Reviews per month distribution zoomed")
plt.show()

# %% [markdown]
# The two above charts are made using subplots in matplotlib and histplot in seaborn. The second graph is basically the same but zoomed for narrower range of better understanding.
#
# Most properties have close 0 monthly reviews. People are clearly not leaving reviews on properties. A visitor booking on airbnb might not want to go to a room with 0 reviews.

# %% [markdown]
# ### Price distribution around the city

# %%
plt.figure(figsize=(10,6))
sns.histplot(df3['price'],binrange=[0,2000])
plt.title("Price distribution")
plt.show()

# %% [markdown]
# The above plot is made using hisplot in seaborn. It shows the price distribution of rooms. binrange is used to narrow down the range between 0 to 2000 for a better looking graph.
#
# Mostly rooms are between 0 to $500.

# %% [markdown]
# ### Top 10 hosts/owners with the most properties througout the city

# %%
df3.host_name.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# The above bar chart shows the hosts with most rooms/properties in the city. It is made by using bar plot in pyplot on value counts method on host_name column.
#
# Michael is the host of more tha 400 properties which is the highest in the city

# %% [markdown]
# ### Top 10 properties with most listing around the city

# %%
df3.name.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Similar to the previous chart, this barchart is made with pyplot by applying value_counts method on the column name in dataframe.
#
# Hillside Hotel has the most property listing around the city

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# This is done taking 2 columns in consideration

# %%
df3.head()
# Out:
#                                         name    host_name neighbourhood_group  \
# 0         Clean & quiet apt home by the park         John            Brooklyn
# 1                      Skylit Midtown Castle     Jennifer           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth           Manhattan
# 3            Cozy Entire Floor of Brownstone  LisaRoxanne            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East        Chris           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 5   Murray Hill  40.74767  -73.97500  Entire home/apt    200               3
#
# ...

# %% [markdown]
# ### Top 10 Most active hosts across the city

# %%
df_host = df3.groupby('host_name')[['price','reviews_per_month','availability_365']].mean().reset_index()


plt.figure(figsize=(10,8))
df_host.sort_values('reviews_per_month',axis=0,inplace=True,ascending=False)
df_host_top = df_host.head(10)

plt.barh(y=df_host_top['host_name'],width=df_host_top['reviews_per_month'])
plt.title("Most Active Hosts")
plt.xlabel("Reviews per month")
plt.ylabel("Host name")
# Out:
# Text(0, 0.5, 'Host name')

# %% [markdown]
# New dataframe is made by grouping host_name and taking the mean values of reviews_per_month column. Then matplotlib is used to plot a horizontal bar chart between the two columns.
#
# From the above graph, we can see that on an average Nalicia is the most active host. We can see that on an average the consumer can book a property with host 'Nalicia' to get the best stay.

# %%
df3.head()
# Out:
#                                         name    host_name neighbourhood_group  \
# 0         Clean & quiet apt home by the park         John            Brooklyn
# 1                      Skylit Midtown Castle     Jennifer           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth           Manhattan
# 3            Cozy Entire Floor of Brownstone  LisaRoxanne            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East        Chris           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 5   Murray Hill  40.74767  -73.97500  Entire home/apt    200               3
#
# ...

# %% [markdown]
# ### Average Price for renting a place in all 5 neighbourhoods

# %%
df3.groupby('neighbourhood_group')['price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# This bar graph is made using pyplot on df3 grouped on neighbourhood_group and mean values taken of price column.
#
# We can see that Manhattan has the costliest properties to rent on Airbnb while Bronx has the cheapest.

# %%
# df_n = df3.groupby('neighbourhood_group')[['neighbourhood','price']].value_counts()
df_n = df3.groupby('neighbourhood_group')['neighbourhood'].value_counts()

# %% [markdown]
# ### Top 5 sub-neighbourhoods with the most listing inside each neighbourhood group

# %%
plt.figure(figsize=(25,20))

plt.subplot(2,3,1)
df_n.loc['Bronx'].head().plot(kind='bar',color='r')
plt.title("Bronx")
plt.xlabel("Sub neighbourhoods")
plt.ylabel("Number of listings")

plt.subplot(2,3,2)
df_n.loc['Brooklyn'].head().plot(kind='bar',color='g')
plt.title("Brooklyn")
plt.xlabel("Sub neighbourhoods")
plt.ylabel("Number of listings")

plt.subplot(2,3,3)
df_n.loc['Manhattan'].head().plot(kind='bar',color='b')
plt.title("Manhattan")
plt.xlabel("Sub neighbourhoods")
plt.ylabel("Number of listings")

plt.subplot(2,3,4)
df_n.loc['Queens'].head().plot(kind='bar',color='y')
plt.title("Queens")
plt.xlabel("Sub neighbourhoods")
plt.ylabel("Number of listings")

plt.subplot(2,3,5)
df_n.loc['Staten Island'].head().plot(kind='bar',color='pink')
plt.title("Staten Island")
plt.xlabel("Sub neighbourhoods")
plt.ylabel("Number of listings")
# Out:
# Text(0, 0.5, 'Number of listings')

# %% [markdown]
# The above bar graphs are made by using subplot from matplolib and barplot from pyplot. Firstly a new df called df_n is formed by neighbourhood_groups and taking total number of records neighbourhood column using value_counts method. For plotting, each neighbourhood_group is called using loc on df_n, and top 5 records are taken with head().
#
#
#
# From the above graph we can understand:
#
#
#
# *   Top 5 places people are visting the most in each neighbourhood based on the number of listings in that area.
# *   Williamsburg in Brooklyn seems like the area that attracts the most visitors.
#
#
# *   Arrochar in Staten Island attracts the least amount of visitors.
# *   Overall Brooklyn looks like the most popular neighbourhood to stay. This makes sense when we compare mean price of each neighbourhood.

# %%
df3.head()
# Out:
#                                         name    host_name neighbourhood_group  \
# 0         Clean & quiet apt home by the park         John            Brooklyn
# 1                      Skylit Midtown Castle     Jennifer           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth           Manhattan
# 3            Cozy Entire Floor of Brownstone  LisaRoxanne            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East        Chris           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 5   Murray Hill  40.74767  -73.97500  Entire home/apt    200               3
#
# ...

# %% [markdown]
# ### More Bivariate analysis on room types

# %%
df_rt_count = df3.groupby('room_type')['number_of_reviews'].sum().reset_index()
df_rt_mean = df3.groupby('room_type')['price'].mean().reset_index()

# %% [markdown]
# 2 new dfs are formed by grouping df3 on room_type and taking total of number of reviews and mean of price column.

# %%
plt.figure(figsize=(10,6))
sns.barplot(df_rt_count, x='room_type',y='number_of_reviews')
plt.title("Total number of reviews for each room type")
plt.show()

# %% [markdown]
# Tha above bar graph show total number of reviews for each room type. Entire apartment and private rooms have way more total reviews than shared rooms.

# %%
plt.figure(figsize=(10,6))
sns.barplot(df_rt_mean, x='room_type',y='price')
plt.title("Average price for each room type")
plt.show()

# %% [markdown]
# The above bar graph shows average price for each room type. Entire apartment are the costliest and shared rooms are the cheapest on an average.

# %%
df_rt = df3.groupby('room_type')['minimum_nights'].mean().reset_index()

plt.figure(figsize=(10,6))
sns.barplot(df_rt,x='room_type',y='minimum_nights')
plt.title("Average number of nights people stay in each room")
# Out:
# Text(0.5, 1.0, 'Average number of nights people stay in each room')

# %% [markdown]
# A new df is formed by grouping room types and taking average of minimum nights column.
#
# Average price of private and shared room is very less when compared to entire home/apt.
#
# Combined with total number of listings, total number of reviews and average price following can be concluded:
#
#
#
# *   Most revenue is coming from Entire home/apartment bookings. The customers booking these properties are leaving the most reviews on an average and are likely to come back.
#
# *   Private room have similar number of listings and reviews but are generating less revenue.
# *   Shared rooms are not preferred as much by customers on airbnb because there are less listings, average price is similar to private rooms and there is lack of privacy as well. But people who chose shared rooms are staying longer on an average then private rooms.

# %%
sns.boxplot(df3,x='neighbourhood_group',y='availability_365')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='availability_365'>

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# This is done taking 3 or more columns in dataframe

# %%
plt.figure(figsize=(10,6))
df_nrt = df3.groupby(['neighbourhood_group','room_type'])['availability_365'].mean().reset_index()
sns.barplot(df_nrt,x='neighbourhood_group',y='availability_365',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='availability_365'>

# %% [markdown]
# A new df is created by grouping df3 on neighbourhood groups and room_type and taking mean  of availability_365 column.
#
# The histogram shows the distribution of room availability for each room type in a year for all neighbourhoods. It is made using seaborn barplot.
#
# 1. Shared rooms are available more days on an average then others for 4 neighbourhood groups.
# 2. Private rooms availability is less in Brooklyn and Manhattan than the other 3 neighbourhood groups.

# %% [markdown]
# ### Map of neighbourhood group

# %%
plt.figure(figsize=(20,16))

plt.subplot(2,2,1)
sns.scatterplot(df3,x='longitude',y='latitude',hue='neighbourhood_group')
plt.title("Neighbourhood group distribution")

plt.subplot(2,2,2)
sns.scatterplot(df3,x='longitude',y='latitude',hue='price')
plt.title("Price distribution")

plt.subplot(2,2,3)
sns.scatterplot(df3,x='longitude',y='latitude',hue='availability_365')
plt.title("Availability distribution")

plt.subplot(2,2,4)
sns.scatterplot(df3,x='longitude',y='latitude',hue='room_type')
plt.title("Room type distribution")
# Out:
# Text(0.5, 1.0, 'Room type distribution')

# %% [markdown]
# The above scatterplots are made using subplot from matplotlib and scatterplot from seaborn. These 4 scatterplot shows location [longitude vs latitude] on neihgbourhood_groups, price, availability and room_type.

# %% [markdown]
# From above we can see that Brookyln and Manhattan has a central location in the city, hence more number of listings are present as it it easy accessible.
